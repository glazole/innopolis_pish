# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint
import datetime as dt
from datetime import timedelta

# %%
requests.get('https://mog.ziax.ru')
# Out:
# <Response [200]>

# %%
url = 'https://mog.ziax.ru/userapi/v1/history/search'
header_params = {
    'Authorization': 'Bearer 9153faf79cd70178b72e9bb5c210db94685d76d8d1056667a13eb84d3623a285',
    'Content-Type': 'application/json'
    }
response = requests.post(url, data=json.dumps({"agent_id":14, "from":"2023-10-01 00:00:00", "to": dt.datetime.now().isoformat()}), headers=header_params)
result = response.json()
pprint(result)
# Out:
# {'data': [{'chat_id': '1698658026.24',
#            'date_time': '30.10.2023 12:27:08',
#            'duration': 27,
#            'phone': '+79093302631',
#            'redirect': None,
#            'status': 'ошибка выполнения WebHook',
#            'successfully': 0},
#           {'chat_id': '1698658462.188',
#            'date_time': '30.10.2023 12:34:24',
#            'duration': 73,
#            'phone': '+79093302631',
#            'redirect': None,
#            'status': 'ошибка выполнения WebHook',
#            'successfully': 0},
#           {'chat_id': '1698658582.231',
#            'date_time': '30.10.2023 12:36:26',
#            'duration': 70,
#            'phone': '+79093302631',
#            'redirect': None,
#            'status': 'ошибка выполнения WebHook',
#            'successfully': 0},
#           {'chat_id': '1698658957.352',
#            'date_time': '30.10.2023 12:42:38',
#            'duration': 28,
#            'phone': '+79626197473',
# ...

# %%
data = result['data']
rows = []
for x in data:
    response = requests.post('https://mog.ziax.ru/userapi/v1/history/show', data=json.dumps({"chat_id": x['chat_id']}), headers=header_params)
    result = response.json()
    rows.append(result)
df = pd.DataFrame(rows)
df
# Out:
#      status                                               data
# 0   success  {'date_time': '30.10.2023 12:27:08', 'agent_id...
# 1   success  {'date_time': '30.10.2023 12:34:24', 'agent_id...
# 2   success  {'date_time': '30.10.2023 12:36:26', 'agent_id...
# 3   success  {'date_time': '30.10.2023 12:42:38', 'agent_id...
# 4   success  {'date_time': '30.10.2023 12:43:31', 'agent_id...
# ..      ...                                                ...
# 88  success  {'date_time': '08.11.2023 09:52:18', 'agent_id...
# 89  success  {'date_time': '08.11.2023 09:54:17', 'agent_id...
# 90  success  {'date_time': '08.11.2023 11:42:57', 'agent_id...
# 91  success  {'date_time': '08.11.2023 14:25:27', 'agent_id...
# 92  success  {'date_time': '08.11.2023 15:39:51', 'agent_id...
#
# [93 rows x 2 columns]

# %%
df = df.data.apply(pd.Series)
df
# Out:
#               date_time  agent_id  agent_name         phone  duration  \
# 0   30.10.2023 12:27:08        14  МОГ жалобы  +79093302631        27
# 1   30.10.2023 12:34:24        14  МОГ жалобы  +79093302631        73
# 2   30.10.2023 12:36:26        14  МОГ жалобы  +79093302631        70
# 3   30.10.2023 12:42:38        14  МОГ жалобы  +79626197473        28
# 4   30.10.2023 12:43:31        14  МОГ жалобы  +79093302631        72
# ..                  ...       ...         ...           ...       ...
# 88  08.11.2023 09:52:18        14  МОГ жалобы  +79057614330        83
# 89  08.11.2023 09:54:17        14  МОГ жалобы  +79057614330       139
# 90  08.11.2023 11:42:57        14  МОГ жалобы  +79035456867        94
# 91  08.11.2023 14:25:27        14  МОГ жалобы  +79262673195        93
# 92  08.11.2023 15:39:51        14  МОГ жалобы  +79152810633        93
#
#    redirect  successfully  is_test                     status  \
# 0      None             0        0  ошибка выполнения WebHook
# ...

# %%
df
# Out:
#               date_time  agent_id  agent_name         phone  duration  \
# 0   30.10.2023 12:27:08        14  МОГ жалобы  +79093302631        27
# 1   30.10.2023 12:34:24        14  МОГ жалобы  +79093302631        73
# 2   30.10.2023 12:36:26        14  МОГ жалобы  +79093302631        70
# 3   30.10.2023 12:42:38        14  МОГ жалобы  +79626197473        28
# 4   30.10.2023 12:43:31        14  МОГ жалобы  +79093302631        72
# ..                  ...       ...         ...           ...       ...
# 88  08.11.2023 09:52:18        14  МОГ жалобы  +79057614330        83
# 89  08.11.2023 09:54:17        14  МОГ жалобы  +79057614330       139
# 90  08.11.2023 11:42:57        14  МОГ жалобы  +79035456867        94
# 91  08.11.2023 14:25:27        14  МОГ жалобы  +79262673195        93
# 92  08.11.2023 15:39:51        14  МОГ жалобы  +79152810633        93
#
#    redirect  successfully  is_test                     status  \
# 0      None             0        0  ошибка выполнения WebHook
# ...

# %%
# 'date_time': '08.11.2023 11:42:57',
#  'agent_id': 14,
#  'agent_name': 'МОГ жалобы',
#  'phone': '+79035456867',
#  'duration': 94,
#  'redirect': None,
#  'successfully': 1,
#  'is_test': 0,
#  'status': 'success',
rows = []
# appending rows
for data in result:
    data_row = result['data']['history']
    phone = result['data']['phone']
    agent = result['data']['agent_id']
    duration = result['data']['duration']
    success = result['data']['successfully']
    test = result['data']['is_test']
    status = result['data']['status']
    for row in data_row:
        row['phone']= phone
        row['status'] = status
        row['success'] = success
        row['agent_id'] = agent
        row['duration'] = duration
        rows.append(row)

# using data frame
df = pd.DataFrame(rows)

df


# for x in df:
#     pd.DataFrame.from_dict(result['data']['history'], orient='columns')
# Out:
#                datetime                user  intent_id  \
# 0   08.11.2023 14:25:27               start        NaN
# 1   08.11.2023 14:25:27                 NaN     3248.0
# 2   08.11.2023 14:25:51                  Да        NaN
# 3   08.11.2023 14:25:51                 NaN     3331.0
# 4   08.11.2023 14:26:15             0 19 65        NaN
# 5   08.11.2023 14:26:15                 NaN     3251.0
# 6   08.11.2023 14:26:27  Меня не устраивает        NaN
# 7   08.11.2023 14:26:27                 NaN     3252.0
# 8   08.11.2023 14:26:45                   1        NaN
# 9   08.11.2023 14:26:45                 NaN     3305.0
# 10  08.11.2023 14:26:54              Проект        NaN
# 11  08.11.2023 14:26:54                 NaN     3307.0
# 12  08.11.2023 14:25:27               start        NaN
# 13  08.11.2023 14:25:27                 NaN     3248.0
# 14  08.11.2023 14:25:51                  Да        NaN
# 15  08.11.2023 14:25:51                 NaN     3331.0
# ...

# %%
url = 'https://mog.ziax.ru/userapi/v1/history/show'
response = requests.post(url, data=json.dumps({"chat_id":'1699368957.52264'}), headers=header_params)
result = response.json()
pprint(result)
# Out:
# {'data': {'agent_id': 14,
#           'agent_name': 'МОГ жалобы',
#           'date_time': '07.11.2023 17:55:57',
#           'duration': 97,
#           'history': [{'datetime': '07.11.2023 17:55:57',
#                        'intent_id': None,
#                        'intent_name': '',
#                        'message_id': 8360630,
#                        'user': 'start'},
#                       {'agent': 'Здравствуйте, вы позвонили в Акционерное '
#                                 'общество Мособл газ. Если у вас возникли '
#                                 'сложности при взаимодействии с филиалами '
#                                 'Мособл газа, по вопросам подключения к '
#                                 'газораспределительным сетям, пожалуйста, '
#                                 'скажите нам. Для оценки работы филиала, '
#                                 'ответьте пожалуйста на пару вопросов. '
# ...

# %%
pprint(result['data']['history'][0])
# Out:
# {'datetime': '07.11.2023 17:55:57',
#  'intent_id': None,
#  'intent_name': '',
#  'message_id': 8360630,
#  'user': 'start'}

# %%
pprint(result['data'])
# Out:
# {'agent_id': 14,
#  'agent_name': 'МОГ жалобы',
#  'date_time': '07.11.2023 17:55:57',
#  'duration': 97,
#  'history': [{'datetime': '07.11.2023 17:55:57',
#               'intent_id': None,
#               'intent_name': '',
#               'message_id': 8360630,
#               'user': 'start'},
#              {'agent': 'Здравствуйте, вы позвонили в Акционерное общество '
#                        'Мособл газ. Если у вас возникли сложности при '
#                        'взаимодействии с филиалами Мособл газа, по вопросам '
#                        'подключения к газораспределительным сетям, пожалуйста, '
#                        'скажите нам. Для оценки работы филиала, ответьте '
#                        'пожалуйста на пару вопросов. Назовите фамилию имя '
#                        'отчество указанные в договоре на догазификацию.',
#               'datetime': '07.11.2023 17:55:57',
#               'intent_id': 3248,
#               'intent_name': 'Default Welcome Intent',
# ...

# %%
df = pd.DataFrame.from_dict(result['data'], orient='columns')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date_time     12 non-null     object
#  1   agent_id      12 non-null     int64
#  2   agent_name    12 non-null     object
#  3   phone         12 non-null     object
#  4   duration      12 non-null     int64
#  5   redirect      0 non-null      object
#  6   successfully  12 non-null     int64
#  7   is_test       12 non-null     int64
#  8   status        12 non-null     object
#  9   history       12 non-null     object
# dtypes: int64(4), object(6)
# memory usage: 1.1+ KB

# %%
pd.DataFrame.from_dict(result['data']['history'], orient='columns')
# Out:
#                datetime                               user  intent_id  \
# 0   07.11.2023 17:55:57                              start        NaN
# 1   07.11.2023 17:55:57                                NaN     3248.0
# 2   07.11.2023 17:56:31              Пафонов олег иванович        NaN
# 3   07.11.2023 17:56:31                                NaN     3331.0
# 4   07.11.2023 17:56:43                           0 3/6 86        NaN
# 5   07.11.2023 17:56:43                                NaN     3346.0
# 6   07.11.2023 17:56:52                        Ни с какими        NaN
# 7   07.11.2023 17:56:52                                NaN     3252.0
# 8   07.11.2023 17:57:10                                  4        NaN
# 9   07.11.2023 17:57:10                                NaN     3305.0
# 10  07.11.2023 17:57:31  Дело все в том что у меня оплачен        NaN
# 11  07.11.2023 17:57:31                                NaN     3307.0
#
# ...

# %%
pd.DataFrame.from_dict(result['data'], orient='columns')
# Out:
#               date_time  agent_id  agent_name         phone  duration  \
# 0   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 1   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 2   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 3   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 4   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 5   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 6   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 7   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 8   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 9   07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 10  07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
# 11  07.11.2023 17:55:57        14  МОГ жалобы  +79151811287        97
#
#    redirect  successfully  is_test   status  \
# ...

# %%
j2 = pd.DataFrame.from_dict(result['data']['history'], orient='columns')
df_json = pd.merge(j2, j2, how='inner', left_on=j2['datetime'], right_on=j2['datetime'])
df_json
# Out:
#                   key_0           datetime_x  \
# 0   07.11.2023 17:55:57  07.11.2023 17:55:57
# 1   07.11.2023 17:55:57  07.11.2023 17:55:57
# 2   07.11.2023 17:55:57  07.11.2023 17:55:57
# 3   07.11.2023 17:55:57  07.11.2023 17:55:57
# 4   07.11.2023 17:56:31  07.11.2023 17:56:31
# 5   07.11.2023 17:56:31  07.11.2023 17:56:31
# 6   07.11.2023 17:56:31  07.11.2023 17:56:31
# 7   07.11.2023 17:56:31  07.11.2023 17:56:31
# 8   07.11.2023 17:56:43  07.11.2023 17:56:43
# 9   07.11.2023 17:56:43  07.11.2023 17:56:43
# 10  07.11.2023 17:56:43  07.11.2023 17:56:43
# 11  07.11.2023 17:56:43  07.11.2023 17:56:43
# 12  07.11.2023 17:56:52  07.11.2023 17:56:52
# 13  07.11.2023 17:56:52  07.11.2023 17:56:52
# 14  07.11.2023 17:56:52  07.11.2023 17:56:52
# 15  07.11.2023 17:56:52  07.11.2023 17:56:52
# 16  07.11.2023 17:57:10  07.11.2023 17:57:10
# 17  07.11.2023 17:57:10  07.11.2023 17:57:10
# 18  07.11.2023 17:57:10  07.11.2023 17:57:10
# 19  07.11.2023 17:57:10  07.11.2023 17:57:10
# ...
