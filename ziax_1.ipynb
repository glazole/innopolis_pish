# %%
import pandas as pd
import numpy as np
import requests
import json
from pprint import pprint #подключили Pprint для красоты выдачи текста

# %%
requests.get('https://mog.ziax.ru')
# Out:
# <Response [200]>

# %%
req = requests.get('https://mog.ziax.ru')
req.status_code
# Out:
# 200

# %%
req.headers
# Out:
# {'Server': 'nginx/1.22.1', 'Content-Type': 'text/html; charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'X-Powered-By': 'PHP/8.2.7', 'Cache-Control': 'no-cache, private', 'Date': 'Tue, 07 Nov 2023 16:37:52 GMT', 'Set-Cookie': 'XSRF-TOKEN=%3D; expires=Tue, 07 Nov 2023 21:37:52 GMT; Max-Age=18000; path=/, laravel_session=
# ...

# %%
from requests.auth import HTTPBasicAuth
basic = HTTPBasicAuth('GlazkovOI@mosoblgaz.ru', '2f66cfc91c30fe9c3228749c282c83e7')

header_params = {
    'GET': 'https://mog.ziax.ru/userapi/v1/history/search',
    'Host': 'mog.ziax.ru',
    'Authorization': 'Bearer 9153faf79cd70178b72e9bb5c210db94685d76d8d1056667a13eb84d3623a285',
    'Content-Type': 'application/json'
    }

requests.get('https://mog.ziax.ru/login', auth=basic, headers=header_params)
# Out:
# <Response [200]>

# %%
url = 'https://mog.ziax.ru/userapi/v1/test?api_token=9153faf79cd70178b72e9bb5c210db94685d76d8d1056667a13eb84d3623a285'
requests.get(url)
# Out:
# <Response [200]>

# %%
url = 'https://mog.ziax.ru/userapi/v1/history/search'

header_params = {
    'Authorization': 'Bearer 9153faf79cd70178b72e9bb5c210db94685d76d8d1056667a13eb84d3623a285',
    'Content-Type': 'application/json'
    }

response = requests.post(url, data={"agent_id":14, "from":"2023-10-01 00:00:00", "to":"2023-11-07 23:59:59"}, headers=header_params)
result = response.json()
print(result)
# Out:
# {'agent_id': ['The agent id field is required.']}

# %%
with open('C:/Users/oigla/#innopolis/innopolis_pish/МОГ жалобы_agent.json', 'r', encoding='utf-8') as f: #открыли файл с данными
    text = json.load(f) #загнали все, что получилось в переменную
    pprint(text) #вывели результат на экран
# Out:
# {'data': {'agent': {'ai_deep': 0,
#                     'api_key': '986ae93f24eeb6d9eb6dafd0b3b224c7',
#                     'description': 'МОГ жалобы',
#                     'id': 14,
#                     'isNeedLearn': 0,
#                     'language': 1,
#                     'sorting': 0,
#                     'spellChecker': 0,
#                     'training': 0,
#                     'training_progress': 0,
#                     'url': 'http://wh:3030',
#                     'webhook': {'Authorization': 'key',
#                                 'Content-type': 'application/json'}},
#           'channels': [10],
#           'entities': {'1': {'ai': 'numbers',
#                              'created_at': None,
#                              'lang': '["ru", "en"]',
#                              'name': 'numbers',
#                              'synonyms': [],
#                              'system': True,
#                              'updated_at': None},
# ...

# %%
for txt in text['personal']: #создали цикл, который будет работать построчно
    print(txt['name'], ':', txt['salary']) #и выводим на экран все, что в значении ключей name и salary
